# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# ## Import dataset
#
# Showing head and tail of dataset

# %%
df = pd.read_csv("gym_members_exercise_tracking_synthetic_data.csv")
df
# Out:
#        Age  Gender  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 0     34.0  Female         86.7        1.86     174    152.0         74.0
# 1     26.0  Female         84.7        1.83     166    156.0         73.0
# 2     22.0    Male         64.8        1.85     187    166.0         64.0
# 3     54.0  Female         75.3        1.82     187    169.0         58.0
# 4     34.0  Female         52.8        1.74     177    169.0         66.0
# ...    ...     ...          ...         ...     ...      ...          ...
# 1795  54.0    Male         88.5        2.00     173    134.0         58.0
# 1796  52.0    Male         84.3        1.69     164    169.0         54.0
# 1797  47.0    Male         70.1        1.84     188    129.0         67.0
# 1798  35.0    Male         49.3        1.71     180    152.0         73.0
# 1799  40.0    Male         79.5        1.92     184    156.0         52.0
#
#       Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                         1.12            712.0     Strength            12.8
# 1                         1.00            833.0     Strength            27.9
# 2                         1.24           1678.0       Cardio            28.7
# 3                         1.45            628.0       Cardio            31.8
# 4                         1.60           1286.0     Strength            26.4
# ...                        ...              ...          ...             ...
# 1795                      1.11           1388.0         HIIT            27.7
# 1796                      0.77           1367.0         HIIT            32.6
# 1797                      1.20           1261.0     Strength            28.4
# 1798                      1.04            956.0       Cardio            32.9
# 1799                      1.29           1178.0     Strength            14.7
#
#       Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                       2.4                            5.0               2.0
# 1                       2.8                            5.0               2.0
# 2                       1.9                            3.0               2.0
# 3                       2.4                            4.0               1.0
# 4                       3.2                            4.0               2.0
# ...                     ...                            ...               ...
# 1795                    3.7                            3.0               2.0
# 1796                    2.9                            3.0               2.0
# 1797                    2.5                            3.0               2.0
# 1798                    1.7                            4.0               3.0
# 1799                    1.5                            4.0               1.0
#
#         BMI
# 0     14.31
# 1     33.49
# 2     12.73
# 3     20.37
# 4     20.83
# ...     ...
# 1795  36.73
# 1796  15.11
# 1797  17.99
# 1798  12.65
# 1799  23.51
#
# [1800 rows x 15 columns]

# %%
df.describe()
# Out:
#                Age  Weight (kg)   Height (m)      Avg_BPM  Resting_BPM  \
# count  1790.000000  1778.000000  1774.000000  1770.000000  1781.000000
# mean     34.475419    67.606637     1.739233   146.259322    63.951151
# std      12.315728    19.861408     0.123892    15.219516     7.936502
# min      18.000000    40.000000     1.500000   120.000000    50.000000
# 25%      23.000000    52.300000     1.650000   133.250000    57.000000
# 50%      33.000000    65.300000     1.730000   146.000000    65.000000
# 75%      45.000000    80.100000     1.820000   160.000000    72.000000
# max      59.000000   129.900000     2.000000   169.000000    74.000000
#
#        Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count               1777.000000      1777.000000     1784.000000
# mean                   1.391598      1033.698931       23.509361
# std                    0.372342       328.049662        5.865557
# min                    0.500000       303.000000       10.000000
# 25%                    1.130000       794.000000       20.500000
# 50%                    1.370000      1030.000000       24.300000
# 75%                    1.640000      1249.000000       27.500000
# max                    2.000000      1783.000000       35.000000
#
#        Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# count            1776.000000                    1742.000000       1743.000000
# mean                2.706644                       3.339265          1.823867
# std                 0.710224                       0.947955          0.746568
# min                 1.500000                       2.000000          1.000000
# 25%                 2.100000                       3.000000          1.000000
# 50%                 2.800000                       3.000000          2.000000
# 75%                 3.400000                       4.000000          2.000000
# max                 3.700000                       5.000000          3.000000
#
#                BMI
# count  1770.000000
# mean     19.957774
# std       6.573175
# min      12.320000
# 25%      14.780000
# 50%      18.690000
# 75%      23.517500
# max      49.840000

# %% [markdown]
# Count line shows us number of non-NA/null observations. We have 1800 rows in each column. Each column have nan values.

# %%
df.isna().sum()
# Out:
# Age                              10
# Gender                           71
# Weight (kg)                      22
# Height (m)                       26
# Max_BPM                          21
# Avg_BPM                          30
# Resting_BPM                      19
# Session_Duration (hours)         23
# Calories_Burned                  23
# Workout_Type                     61
# Fat_Percentage                   16
# Water_Intake (liters)            24
# Workout_Frequency (days/week)    58
# Experience_Level                 57
# BMI                              30
# dtype: int64

# %% [markdown]
# isna function show number of nan values in each column, which proves that dataset has nan fields.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            1790 non-null   float64
#  1   Gender                         1729 non-null   object
#  2   Weight (kg)                    1778 non-null   float64
#  3   Height (m)                     1774 non-null   float64
#  4   Max_BPM                        1779 non-null   object
#  5   Avg_BPM                        1770 non-null   float64
#  6   Resting_BPM                    1781 non-null   float64
#  7   Session_Duration (hours)       1777 non-null   float64
#  8   Calories_Burned                1777 non-null   float64
#  9   Workout_Type                   1739 non-null   object
#  10  Fat_Percentage                 1784 non-null   float64
#  11  Water_Intake (liters)          1776 non-null   float64
#  12  Workout_Frequency (days/week)  1742 non-null   float64
#  13  Experience_Level               1743 non-null   float64
#  14  BMI                            1770 non-null   float64
# dtypes: float64(12), object(3)
# memory usage: 211.1+ KB

# %% [markdown]
# We can observe that besides 'Gender' and 'Workout_Type' which are obvious are not numerical columns there is a 'Max_BPM' column with Object data type included

# %% [markdown]
# ## Cleaning

# %% [markdown]
# Change of data type in the Max_BPM column

# %%
df['Max_BPM'] = pd.to_numeric(df['Max_BPM'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            1790 non-null   float64
#  1   Gender                         1729 non-null   object
#  2   Weight (kg)                    1778 non-null   float64
#  3   Height (m)                     1774 non-null   float64
#  4   Max_BPM                        1772 non-null   float64
#  5   Avg_BPM                        1770 non-null   float64
#  6   Resting_BPM                    1781 non-null   float64
#  7   Session_Duration (hours)       1777 non-null   float64
#  8   Calories_Burned                1777 non-null   float64
#  9   Workout_Type                   1739 non-null   object
#  10  Fat_Percentage                 1784 non-null   float64
#  11  Water_Intake (liters)          1776 non-null   float64
#  12  Workout_Frequency (days/week)  1742 non-null   float64
#  13  Experience_Level               1743 non-null   float64
#  14  BMI                            1770 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 211.1+ KB

# %% [markdown]
# We can not fillin columns 'Gender' and 'Workout_Type' with average values. So I prefer to drop out lines with blank fields in this columns.
# I think in real world age is super important for fitness data. So I decided not to fill it with average and delete lines with nans.

# %%
df = df.dropna(subset = ['Age', 'Gender', 'Workout_Type'])
df.isna().sum()
# Out:
# Age                               0
# Gender                            0
# Weight (kg)                      21
# Height (m)                       26
# Max_BPM                          27
# Avg_BPM                          27
# Resting_BPM                      16
# Session_Duration (hours)         20
# Calories_Burned                  20
# Workout_Type                      0
# Fat_Percentage                   15
# Water_Intake (liters)            22
# Workout_Frequency (days/week)    54
# Experience_Level                 52
# BMI                              27
# dtype: int64

# %% [markdown]
# If we delete all the lines with nans we will lose about 1/3 of dataset. Therefore I decided to fillin fileds with average values for each column.

# %%
pd.set_option('future.no_silent_downcasting', True)
columns_to_fill = [
    "Avg_BPM", "Max_BPM", "Weight (kg)", "Height (m)", "Resting_BPM",
    "Session_Duration (hours)", "Calories_Burned", "Fat_Percentage",
    "Water_Intake (liters)", "Workout_Frequency (days/week)", "Experience_Level", "BMI"
]

for col in columns_to_fill:
    mean_value = df[col].mean()
    df.loc[:, col] = df[col].fillna(mean_value)
df.isna().sum()
# Out:
# Age                              0
# Gender                           0
# Weight (kg)                      0
# Height (m)                       0
# Max_BPM                          0
# Avg_BPM                          0
# Resting_BPM                      0
# Session_Duration (hours)         0
# Calories_Burned                  0
# Workout_Type                     0
# Fat_Percentage                   0
# Water_Intake (liters)            0
# Workout_Frequency (days/week)    0
# Experience_Level                 0
# BMI                              0
# dtype: int64

# %%
valid_workout_types = ["Strength", "Cardio", "HIIT", "Yoga"]
df.loc[~df['Workout_Type'].isin(valid_workout_types), 'Workout_Type'] = None
df = df.dropna(subset=['Workout_Type']).reset_index(drop=True)

# %% [markdown]
# ## Overview

# %%
df.hist(bins=20, figsize=(16,12))
plt.show()

# %% [markdown]
# We can see that there is no zero values in data.

# %%
fig = px.pie(df, names="Gender", title="Gender Distribution")
fig.show()
# Out:
# <div>                            <div id="7fe317e2-3b0d-44bb-8c27-0887b59ce092" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fe317e2-3b0d-44bb-8c27-0887b59ce092")) {                    Plotly.newPlot(                        "7fe317e2-3b0d-44bb-8c27-0887b59ce092",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Gender=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Female","Female","Male","Female","Female","Female","Female","Female","Female","Female","Female","Male","Female","Female","Female","Male","Female","Female","Male","Female","Female","Male","Male","Male","Male","Male","Female","Male","Male","Female","Female","Female","Male","Female","Male","Male","Female","Male","Female","Male","Male","Female","Female","Female","Female","Female","Female","Male","Female","Female","Female","Female","Male","Female","Female","Female","Female","Male","Female","Male","Male","Female","Male","Female","Female","Female","Male","Female","Male","Male","Male","Female","Female","Female","Female","Male","Female","Female","Male","Male","Female","Male","Male","Male","Female","Female","Female","Male","Male","Female","Male","Male","Male","Female","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Male","Male","Female","Male","Female","Male","Female","Female","Female","Female","Female","Male","Male","Female","Male","Male","Female","Female","Female","Male","Female","Male","Female","Female","Male","Male","Male","Female","Female","Female","Female","Female","Male","Male","Female","Male","Male","Female","Female","Female","Female","Male","Male","Female","Male","Male","Male","Female","Male","Female","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male","Female","Male","Male","Male","Female","Female","Female","Female","Male","Male","Male","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Female","Male","Male","Male","Female","Female","Female","Male","Male","Female","Male","Male","Male","Female","Female","Male","Male","Male","Female","Male","Female","Male","Female","Female","Male","Male","Male","Female","Female","Female","Female","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Female","Female","Male","Female","Female","Female","Female","Female","Female","Female","Female","Female","Male","Male","Male","Male","Female","Male","Female","Male","Female","Female","Female","Male","Female","Female","Female","Male","Female","Female","Female","Female","Male","Female","Male","Male","Male","Female","Male","Male","Male","Female","Female","Female","Female","Female","Female","Male","Female","Female","Female","Female","Female","Male","Male","Male","Male","Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Female","Female","Female","Male","Female","Male","Female","Female","Male","Female","Female","Female","Female","Male","Male","Female","Female","Female","Male","Male","Male","Female","Female","Female","Male","Male","Female","Female","Male","Female","Male","Female","Male","Male","Male","Male","Male","Female","Male","Female","Female","Female","Female","Male","Male","Female","Female","Male","Female","Female","Female","Male","Female","Male","Male","Female","Female","Female","Female","Male","Male","Male","Female","Female","Female","Female","Female","Female","Male","Female","Female","Male","Female","Female","Female","Male","Male","Male","Female","Male","Female","Male","Female","Female","Male","Male","Male","Male","Female","Male","Male","Male","Male","Female","Female","Female","Male","Male","Female","Female","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Female","Female","Female","Male","Female","Male","M ...

# %%
fig = px.bar(df, x = 'Workout_Type', color="Workout_Type", title = 'Workout Type Distribution')
fig.show()
# Out:
# <div>                            <div id="4de57970-783c-4fe7-8f56-b3393a9f513d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4de57970-783c-4fe7-8f56-b3393a9f513d")) {                    Plotly.newPlot(                        "4de57970-783c-4fe7-8f56-b3393a9f513d",                        [{"alignmentgroup":"True","hovertemplate":"Workout_Type=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"
.7,40.0,87.9,74.2,40.5,43.8,45.7,60.9,59.0,80.0,50.2,59.2,53.5,83.1,70.4,50.3,65.3,78.3,79.4,72.6,78.3,54.2,45.5,59.0,89.2,108.3,45.9,88.5,62.5,79.0,40.0,89.3,102.6,50.3,46.0,40.0,49.3,67.9,103.8,85.1,74.1,47.9,78.2,69.2,91.3,45.1,54.2,83.6,58.0,45.6,40.0,40.0,83.5,81.9,40.0,55.4,59.9,51.6,55.4,80.2,100.2,50.8,77.0,50.1,99.3,67.5,41.4,80.4,71.8,45.8,106.8,88.4,76.1,40.0,67.1,53.9,79.3,56.5,57.2,74.3,67.80652041438148,62.9,98.6,102.8,47.5,85.9,70.2,44.2,56.8,48.7,72.3,68.0,75.9,64.6,68.7,61.1,70.1,66.8,62.7,49.0,68.2,85.1,63.7,46.9,100.3,65.0,59.9,59.1,72.8,65.0,74.2,61.2,63.3,73.0,61.7,71.9,115.6,64.7,63.6,65.7,65.5,90.5,40.0,76.8,92.4,54.3,64.1,45.3,76.0,40.0,62.9,40.0,75.2,78.4,57.0,40.0,45.0,78.5,49.4,50.3,61.0,40.0,102.2,40.0,69.6,56.8,99.4,64.3,40.0,85.4,72.9,48.8,113.1,53.7,68.8,43.4,40.0,44.2,64.1,40.0,68.9,105.7,61.9,42.6,97.4,62.4,65.7,51.4,75.2,40.0,80.5,109.4,40.0,79.5,68.5,87.5,55.4,58.2,95.2,41.4,40.0,72.1,129.9,69.0,68.2,105.0,129.9,61.1,93.1,57.1,64.4,40.0,76.3,71.2,102.1,63.6,88.6,108.7,61.4,69.2,40.0,46.0,67.80652041438148,110.3,98.0,94.5,57.6,62.9,50.0,104.3,61.2,82.5,58.3,69.6,81.1,65.7,91.2,98.5,65.2,46.3,45.0,74.8,61.1,44.3,96.2,40.0,83.3,61.5,40.0,68.6,77.9,40.9,90.9,88.8,83.2,99.1,91.0,49.6,59.6,53.7,58.9,61.7,106.3,73.2,69.9,62.3,98.3,46.5,64.0,45.1,77.9,66.4,54.0 ...

# %% [markdown]
# Height and Weight distribution completly independent from gender in this dataset.

# %% [markdown]
# Let's see if the number of calories burned depends on the duration of the workout

# %%
subset = 'Cardio', 'HIIT'
fig = px.scatter(df.loc[df['Workout_Type'].isin(['Cardio', 'HIIT'])], x='Session_Duration (hours)', y='Calories_Burned', color = 'Workout_Type', facet_col='Workout_Type')
fig.show()
# Out:
# <div>                            <div id="f753650b-e136-47fd-abad-946c9d091556" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f753650b-e136-47fd-abad-946c9d091556")) {                    Plotly.newPlot(                        "f753650b-e136-47fd-abad-946c9d091556",                        [{"hovertemplate":"Workout_Type=Cardio\u003cbr\u003eSession_Duration (hours)=%{x}\u003cbr\u003eCalories_Burned=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cardio","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"
IIT","HIIT","Yoga","Strength","Yoga","Cardio","Strength","Cardio","Yoga","Strength","Yoga","Yoga","Yoga","Strength","Cardio","Yoga","Yoga","HIIT","Strength","HIIT","Cardio","HIIT","Yoga","Strength","Cardio","HIIT","Cardio","Cardio","HIIT","Strength","HIIT","Strength","Strength","Cardio","Yoga","Yoga","Yoga","Strength","HIIT","Yoga","Cardio","Strength","Cardio","HIIT","Strength","Cardio","Cardio","Yoga","Yoga","HIIT","Yoga","HIIT","HIIT","Cardio","Cardio","Strength","Yoga","Cardio","Strength","Cardio","HIIT","Cardio","Strength","Strength","Strength","Cardio","Cardio","Cardio","HIIT","Yoga","Yoga","HIIT","Yoga","Cardio","Cardio","Yoga","Strength","Cardio","Yoga","Yoga","Yoga","Cardio","Strength","HIIT","Yoga","Cardio","HIIT","Strength","Cardio","Yoga","Strength","Strength","Strength","Yoga","Cardio","HIIT","Yoga","HIIT","Yoga","HIIT","HIIT","Yoga","Strength","Strength","Strength","Yoga","HIIT","Yoga","Cardio","Yoga","Strength","HIIT","Strength","Strength","HIIT","Yoga","Strength","Cardio","HIIT","Strength","Strength","Strength","Yoga","Yoga","Yoga","Cardio","Yoga","HIIT","Strength","Strength","Strength","Yoga","Strength","Strength","Yoga","Cardio","HIIT","HIIT","HIIT","Cardio","Yoga","Yoga","Yoga","HIIT","Cardio","Cardio","Yoga","Strength","Strength","Yoga","Cardio","Yoga","Cardio","Strength","Cardio","HIIT","Yoga","Cardio","Yoga","Cardio","Cardio","Cardio","Strength","HIIT","Yoga","Yoga","Yoga","Strength","Yoga","HIIT","Strength","Strength","HIIT","Yoga","Strength","Strength","HIIT","Yoga","HIIT","HIIT","Cardio","Strength","Yoga","Cardio","HIIT","Cardio","Yoga","Cardio","HIIT","Yoga","Strength","Yoga","HIIT","Cardio","Cardio","Yoga","HIIT","Yoga","Yoga","Strength","Yoga","Cardio","Yoga","Cardio","Cardio","Yoga","Yoga","Yoga","HIIT","Strength","Strength","Yoga","HIIT","Strength","Strength","Strength","HIIT","HIIT","Cardio","Strength","HIIT","HIIT","Cardio","Yoga","Cardio","Cardio","Cardio","Cardio","Cardio","Yoga","Strength","HIIT","Cardio","Cardio","Yoga","Strength","Yoga","Strength","Yoga","Strength","Cardio","Yoga","Cardio","Yoga","Cardio","Cardio","Cardio","HIIT","Yoga","Yoga","HIIT","Strength","Cardio","Cardio","Strength","HIIT","Strength","Strength","Strength","Yoga","Strength","HIIT","Yoga","Cardio"," ...

# %% [markdown]
# We do not see significant difference in session duration for different workout types.

# %%
fig = px.scatter(df.loc[df['Experience_Level'] == 3], y ='Water_Intake (liters)', x ='Fat_Percentage', color = 'Session_Duration (hours)',title='Water Intake affecting on Fat Percentage')
fig.show()

# %% [markdown]
# This graph shows dependence of water inteka to fat percentage for people with experience level 3 for different session duration.
# We can observe that there is no correlation between fat percentage and water intake.

# %%
avg_bpm_df = df.groupby("Workout_Type", as_index=False)["Avg_BPM"].mean()
fig = px.bar(avg_bpm_df, x="Workout_Type", y="Avg_BPM",
             title="Average BPM during different workouts", color="Workout_Type")
fig.show()
# Out:
# <div>                            <div id="9d6763da-863d-41e6-adff-d9ec31cab40e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d6763da-863d-41e6-adff-d9ec31cab40e")) {                    Plotly.newPlot(                        "9d6763da-863d-41e6-adff-d9ec31cab40e",                        [{"alignmentgroup":"True","hovertemplate":"Workout_Type=%{x}\u003cbr\u003eAvg_BPM=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cardio","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cardio","offsetgroup":"Cardio","orientation":"v","showlegend":true,"textposition":"auto","x":["Cardio"],"xaxis":"x","y":[146.21203058103976],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Workout_Type=%{x}\u003cbr\u003eAvg_BPM=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HIIT","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"HIIT","offsetgroup":"HIIT","orientation":"v","showlegend":true,"textposition":"auto","x":["HIIT"],"xaxis":"x","y":[144.99098184657427],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Workout_Type=%{x}\u003cbr\u003eAvg_BPM=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Strength","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Strength","offsetgroup":"Strength","orientation":"v","showlegend":true,"textposition":"auto","x":["Strength"],"xaxis":"x","y":[146.7228679757012],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Workout_Type=%{x}\u003cbr\u003eAvg_BPM=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yoga","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Yoga","offsetgroup":"Yoga","orientation":"v","showlegend":true,"textposition":"auto","x":["Yoga"],"xaxis":"x","y":[146.33206852528133],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66 ...

# %% [markdown]
# It is clearly seen that therre is almost no difference between workouts in BPM.

# %% [markdown]
# ## Hypothesis 1 checking

# %% [markdown]
# Dataset is randomly generated and each column filled independently.

# %% [markdown]
# ### Prove

# %% [markdown]
# BMI index is equal to weight divided by squared height.
# Let's create a new column called Calculated_BMI.

# %% [markdown]
# ### Data Transformation 1
#
# Calculating BMI index according to formula: BMI = Weight / (Height) ^ 2

# %%
df['Calculated_BMI'] = (df['Weight (kg)'] / (df['Height (m)'] ** 2))
subset = ['BMI', 'Calculated_BMI', 'Weight (kg)', 'Height (m)']
df[subset]
# Out:
#         BMI  Calculated_BMI  Weight (kg)  Height (m)
# 0     14.31       25.060701         86.7        1.86
# 1     33.49       25.291887         84.7        1.83
# 2     12.73       18.933528         64.8        1.85
# 3     20.37       22.732762         75.3        1.82
# 4     20.83       17.439556         52.8        1.74
# ...     ...             ...          ...         ...
# 1625  36.73       22.125000         88.5        2.00
# 1626  15.11       29.515773         84.3        1.69
# 1627  17.99       20.705340         70.1        1.84
# 1628  12.65       16.859889         49.3        1.71
# 1629  23.51       21.565755         79.5        1.92
#
# [1630 rows x 4 columns]

# %%
plt.figure(figsize=(5,3))
subset = ['BMI', 'Calculated_BMI', 'Weight (kg)', 'Height (m)']
sns.heatmap(df[subset].corr(numeric_only = True), annot = True, cmap="Greys")
plt.title('Correlation');

# %% [markdown]
# Calculated_BMI is highly dependent on Weight and Height.
# BMI in dataset is not depended on Weight and Height.
# There is no dependency between BMI and Calculated_BMI.

# %%
fig = px.scatter(df, x = 'Weight (kg)', y = 'Calculated_BMI', color = 'Height (m)')
fig.show()

# %%
fig = px.scatter(df, x = 'Weight (kg)', y = 'BMI', color = 'Height (m)')
fig.show()

# %% [markdown]
# We see that Calculated_BMI is depended on Weight and Height.
# BMI from dataset is completly independend.

# %% [markdown]
# ### Data Transformation 2
#
# Calculating if Avg_BPM is bigger than Max_BPM. It is contradicting situation.

0,155.0,148.0,169.0,153.0,139.0,121.0,166.0,163.0,136.0,158.0,141.0,169.0,155.0,127.0,152.0,120.0,149.0,166.0,125.0,133.0,123.0,129.0,130.0,140.0,127.0,146.10152905198777,162.0,140.0,154.0,155.0,139.0,159.0,141.0,159.0,128.0,146.10152905198777,123.0,158.0,168.0,137.0,146.0,137.0,134.0,149.0,161.0,163.0,121.0,120.0,127.0,156.0,129.0,169.0,136.0,156.0,152.0,140.0,153.0,140.0,127.0,167.0,138.0,145.0,129.0,127.0,138.0,151.0,168.0,142.0,153.0,142.0,165.0,135.0,130.0,162.0,120.0,161.0,163.0,120.0,145.0,120.0,135.0,133.0,143.0,131.0,153.0,127.0,150.0,142.0,150.0,146.0,150.0,158.0,144.0,120.0,162.0,131.0,120.0,155.0,167.0,140.0,137.0,136.0,128.0,169.0,169.0,151.0,167.0,169.0,136.0,161.0,142.0,124.0,148.0,132.0,136.0,127.0,159.0,138.0,130.0,156.0,134.0,144.0,167.0,148.0,129.0,156.0],"xaxis":"x","y":[174.0,166.0,177.0,181.0,186.0,177.0,184.0,199.0,178.0,192.0,166.0,192.0,194.0,161.0,164.0,167.0,180.0,188.0,177.0,175.0,193.0,170.0,194.0,178.0,171.0,180.17247706422017,184.0,187.0,188.0,172.0,198.0,176.0,186.0,190.0,169.0,181.0,199.0,178.0,193.0,194.0,171.0,181.0,170.0,169.0,199.0,163.0,196.0,177.0,196.0,177.0,194.0,184.0,193.0,191.0,176.0,190.0,168.0,169.0,196.0,185.0,174.0,177.0,199.0,176.0,186.0,168.0,162.0,174.0,174.0,187.0,195.0,173.0,199.0,164.0,169.0,177.0,185.0,169.0,191.0,198.0,199.0,175.0,194.0,187.0,192.0,193.0,172.0,192.0,191.0,179.0,199.0,181.0,198.0,172.0,168.0,198.0,164.0 ...

# %% [markdown]
# Another prove that dataset is generated randomly and columns are independent. On this graph we see Max_BPM and Avg_BPM. We see that where is no dependency bethween this two columns. Moreover, there are cases when Average BPM is higher than Maximum BPM which is not realistic.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1630 entries, 0 to 1629
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            1630 non-null   float64
#  1   Gender                         1630 non-null   object
#  2   Weight (kg)                    1630 non-null   float64
#  3   Height (m)                     1630 non-null   float64
#  4   Max_BPM                        1630 non-null   float64
#  5   Avg_BPM                        1630 non-null   float64
#  6   Resting_BPM                    1630 non-null   float64
#  7   Session_Duration (hours)       1630 non-null   float64
#  8   Calories_Burned                1630 non-null   float64
#  9   Workout_Type                   1630 non-null   object
#  10  Fat_Percentage                 1630 non-null   float64
#  11  Water_Intake (liters)          1630 non-null   float64
#  12  Workout_Frequency (days/week)  1630 non-null   float64
#  13  Experience_Level               1630 non-null   float64
#  14  BMI                            1630 non-null   float64
#  15  Calculated_BMI                 1630 non-null   float64
#  16  Check_BPM                      1630 non-null   bool
# dtypes: bool(1), float64(14), object(2)
# memory usage: 205.5+ KB

# %% [markdown]
# I created boolean column.

# %% [markdown]
# ## Conclusion
#
# Dataset is interesting for data cleaning and wide variety of different columns. Unfortunatly it is randomly generated and it is not possible to use this data for conclusions.
